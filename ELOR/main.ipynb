# %%
import pandas as pd

from functions import *

# %%
df = pd.read_csv("Datasets/fixtures.csv")
df = set_ELO(df)
winper = WinPer()
winper.to_csv("Datasets/winper.csv", index=False)
df = update_ELO(df)
df.to_csv("Datasets/ELO.csv", index=False)
get_rank = get_rank(df)
get_rank.to_csv("Datasets/get_rank.csv", index=False)
performance = calculate_team_performance(df)
performance.to_csv("Datasets/performance.csv", index=False)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 14747.65it/s]
# 100%|██████████| 9076/9076 [00:03<00:00, 2908.75it/s]

# %%
df.head()
# Out:
#    Year Home_Team  Home_Score  Away_Score Away_Team         Date  Margin  \
# 0  1890     Wales           2           8  Scotland   1 Feb 1890      -6
# 1  1890   England           0           1     Wales  15 Feb 1890      -1
# 2  1890  Scotland           5           0   Ireland  22 Feb 1890       5
# 3  1890  Scotland           0           6   England   1 Mar 1890      -6
# 4  1890   Ireland           3           3     Wales   1 Mar 1890       0
#
#    Home_Away_Draw Prob_Home Prob_Away Home_Rating_Updated Away_Rating_Updated
# 0             0.0     0.606     0.394         1452.813294         1547.186706
# 1             0.0     0.669     0.331         1481.456086         1471.357208
# 2             1.0     0.669     0.331         1570.910758         1476.275948
# 3             0.0      0.72      0.28         1514.845032         1537.521812
# 4             0.5     0.613     0.387         1476.275948         1471.357208

# %%
df.tail()
# Out:
#       Year     Home_Team  Home_Score  Away_Score     Away_Team       Date  \
# 9071  2021       Georgia          28          17       Romania  3/28/2021
# 9072  2021       Belgium          21          23   Netherlands  5/29/2021
# 9073  2021       Burundi           3          52  Burkina Faso   6/5/2021
# 9074  2021       Burundi           3          81      Cameroon   6/9/2021
# 9075  2021  Burkina Faso          17          13      Cameroon  6/13/2021
#
#       Margin  Home_Away_Draw Prob_Home Prob_Away Home_Rating_Updated  \
# 9071      11             1.0     0.889     0.111         2250.591294
# 9072      -2             0.0     0.381     0.619         1669.034756
# 9073     -49             0.0     0.084     0.916         1052.611092
# 9074     -78             0.0     0.209     0.791         1016.036993
# 9075       4             1.0     0.807     0.193         1580.696877
#
#      Away_Rating_Updated
# 9071         1941.572866
# 9072           1861.7581
# 9073          1568.24895
# 9074         1395.181833
# 9075         1382.733906
