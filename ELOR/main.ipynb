# %%
import pandas as pd

from functions import *

# %%
df = pd.read_csv("Datasets/fixtures.csv")
df = set_ELO(df)
winper = WinPer()
winper.to_csv("Datasets/winper.csv", index=False)
df = update_ELO(df)
df.to_csv("Datasets/ELO.csv", index=False)
get_rank = get_rank(df)
get_rank.to_csv("Datasets/get_rank.csv", index=False)
performance = calculate_team_performance(df)
performance.to_csv("Datasets/performance.csv", index=False)
# Out:
# ...
# 100%|██████████| 16034/16034 [00:04<00:00, 3370.52it/s]

# %%
df.head()
# Out:
#    Year Home_Team  Home_Score  Away_Score Away_Team       Date  Margin  \
# 0  1893     Wales          12          11   England   1/7/1893       1
# 1  1893   Ireland           0           4   England   2/4/1893      -4
# 2  1893  Scotland           0           9     Wales   2/4/1893      -9
# 3  1893   Ireland           0           0  Scotland  2/20/1893       0
# 4  1893   England           0           8  Scotland   3/4/1893      -8
#
#    Home_Away_Draw Prob_Home Prob_Away Home_Rating_Updated Away_Rating_Updated
# 0             1.0     0.606     0.394         1510.914965         1489.085035
# 1             0.0     0.621     0.379          1460.01428         1529.070755
# 2             0.0     0.591     0.409         1445.553543         1565.361422
# 3             0.5     0.626     0.374          1460.01428         1445.553543
# 4             0.0     0.714     0.286         1466.373156         1508.251142

# %%
df.tail()
# Out:
#        Year              Home_Team  Home_Score  Away_Score  \
# 16029  2026               Stormers          24          31
# 16030  2026       Tokyo Sungoliath          22          27
# 16031  2026        Toyota Verblitz          24          38
# 16032  2026           US Montauban          22          47
# 16033  2026  Yokohama Canon Eagles          33          15
#
#                    Away_Team       Date  Margin  Home_Away_Draw Prob_Home  \
# 16029               Connacht  4/18/2026      -7             0.0     0.603
# 16030          Kubota Spears  4/18/2026      -5             0.0     0.289
# 16031  Kobelco Kobe Steelers  4/18/2026     -14             0.0     0.218
# 16032          RC Toulonnais  4/18/2026     -25             0.0     0.175
# 16033        Urayasu D-Rocks  4/18/2026      18             1.0     0.816
#
#       Prob_Away Home_Rating_Updated Away_Rating_Updated
# 16029     0.397         1596.441754         1699.326718
# ...
